# %%
import pandas as pd
import yfinance as yf
import datetime
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
import datetime

Reliance_industries = yf.download('RELIANCE.NS',
                        start=datetime.datetime(2019, 1, 1),
                        end=datetime.datetime(2020, 1, 1))

print(Reliance_industries)

# %%
Reliance_industries = yf.download('RELIANCE.NS',
                          start = datetime.datetime(2019,1,1),
                          end = datetime.datetime(2020,1,1))
Hdfc_bank = yf.download('HDB',
                          start = datetime.datetime(2019,1,1),
                          end = datetime.datetime(2020,1,1))
Trident = yf.download('TRIDENT.NS',
                             start = datetime.datetime(2019,1,1),
                             end = datetime.datetime(2020,1,1))
                            
type(Reliance_industries), type(Hdfc_bank), type(Trident)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# (pandas.core.frame.DataFrame,
#  pandas.core.frame.DataFrame,
#  pandas.core.frame.DataFrame)

# %%
Reliance_industries.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-01-01  1114.683960  1116.714722  1099.676147  1110.473877  1089.558228
# 2019-01-02  1104.034912  1116.417480  1090.661621  1096.010864  1075.367676
# 2019-01-03  1097.100586  1104.133911  1079.864014  1082.489136  1062.100464
# 2019-01-04  1087.095459  1094.079224  1070.948486  1088.333740  1067.835083
# 2019-01-07  1096.605225  1107.947754  1090.661621  1094.376465  1073.764038
#
#              Volume
# Date
# 2019-01-01  4498087
# 2019-01-02  7212697
# 2019-01-03  7517041
# 2019-01-04  8545382
# 2019-01-07  5565822

# %% [markdown]
# #### Showing Opening ,Closing, High prices, Low prices for year 2019-2020 of Relaince_Industries Shares.

# %%
Reliance_industries['Open'].plot(label = "Reliance_industries - open_prices")
Reliance_industries['Close'].plot(label = "Reliance_industries - close_prices")
Reliance_industries['High'].plot(label = "Reliance_industries - High_prices")
Reliance_industries['Low'].plot(label = "Reliance_industries - low_prices")
plt.title('Reliance Share Analysis')
plt.ylabel('Share price')
# Out:
# Text(0, 0.5, 'Share price')

# %% [markdown]
# #### Showing Opening ,Closing, High prices, Low prices for year 2019-2020 of HDFC Bank Shares.

# %%
Hdfc_bank['Open'].plot(label = "HDFC Bank - open_prices")
Hdfc_bank['Close'].plot(label = "HDFC Bank - close_prices")
Hdfc_bank['High'].plot(label = "HDFC Bank - High_prices")
Hdfc_bank['Low'].plot(label = "HDFC Bank - low_prices")

plt.title('HDFC Bank Share Analysis')
plt.ylabel('Share price')
# Out:
# Text(0, 0.5, 'Share price')

# %% [markdown]
# #### Showing Opening ,Closing, High prices, Low prices for year 2019-2020 of Trident ltd Share.

# %%
Trident['Open'].plot(label = "Trident - open_prices")
Trident['Close'].plot(label = "Trident - close_prices")
Trident['High'].plot(label = "Trident - High_prices")
Trident['Low'].plot(label = "Trident - low_prices")

plt.title('Trident Share Analysis')
plt.ylabel('Share price')
# Out:
# Text(0, 0.5, 'Share price')

# %% [markdown]
# ## Showing total traded amount for Trident ltd Share.

# %%
Trident['Total traded'] = Trident['Open'] * Trident['Volume']
Trident['Total traded'].plot(label='Trident')
Trident.head
# Out:
# <bound method NDFrame.head of              Open   High   Low  Close  Adj Close    Volume  Total traded
# Date
# 2019-01-01  6.620  6.895  6.62  6.820   5.939979  13560030  8.976740e+07
# 2019-01-02  6.770  6.840  6.65  6.745   5.874656   4528870  3.066045e+07
# 2019-01-03  6.790  6.850  6.71  6.730   5.861593   5166720  3.508203e+07
# 2019-01-04  6.765  6.790  6.63  6.675   5.813689   3540830  2.395371e+07
# 2019-01-07  6.700  6.800  6.70  6.725   5.857237   3584990  2.401943e+07
# ...           ...    ...   ...    ...        ...       ...           ...
# 2019-12-24  7.050  7.100  6.85  6.900   6.356816   5623120  3.964300e+07
# 2019-12-26  7.000  7.000  6.75  6.800   6.264688   6342255  4.439578e+07
# 2019-12-27  6.900  6.950  6.60  6.650   6.126496   7635037  5.268176e+07
# 2019-12-30  6.650  6.850  6.55  6.700   6.172560   8716563  5.796514e+07
# 2019-12-31  6.750  6.750  6.60  6.700   6.172560   4424300  2.986402e+07
#
# [243 rows x 7 columns]>

# %% [markdown]
# ## Comparison between all the 3 shares(Reliance, HDFC Bank and Trident)

# %%
Reliance_industries['Open'].plot(label = "Reliance_industries - open_prices")
Hdfc_bank['Open'].plot(label = "HDFC Bank - open_prices")
Trident['Open'].plot(label = "Trident - open_prices")
plt.legend()
plt.show()

# %%
Trident['Close'].plot(label = "Trident - close_prices")
Hdfc_bank['Close'].plot(label = "HDFC Bank - close_prices")
Reliance_industries['Close'].plot(label = "Reliance_industries - close_prices")
plt.legend()
plt.show()

# %% [markdown]
# ### Showing relation betwen shares()

# %%
Stock_Share = pd.concat([Reliance_industries['Open'],Hdfc_bank['Open'],Trident['Open']],axis = 1)
scatter_matrix(Stock_Share)
# Out:
# array([[<AxesSubplot:xlabel='Open', ylabel='Open'>,
#         <AxesSubplot:xlabel='Open', ylabel='Open'>,
#         <AxesSubplot:xlabel='Open', ylabel='Open'>],
#        [<AxesSubplot:xlabel='Open', ylabel='Open'>,
#         <AxesSubplot:xlabel='Open', ylabel='Open'>,
#         <AxesSubplot:xlabel='Open', ylabel='Open'>],
#        [<AxesSubplot:xlabel='Open', ylabel='Open'>,
#         <AxesSubplot:xlabel='Open', ylabel='Open'>,
#         <AxesSubplot:xlabel='Open', ylabel='Open'>]], dtype=object)

# %% [markdown]
# ### Return that are provided by the specific share on daily basis

# %%
Reliance_industries["Returns"] = (Reliance_industries['Close']/Reliance_industries['Close'].shift(1))-1
Hdfc_bank["Returns"] = (Hdfc_bank['Close']/Hdfc_bank['Close'].shift(1))-1
Trident["Returns"] = (Trident['Close']/Trident['Close'].shift(1))-1

# %% [markdown]
# ### Plotting them in histogram

# %%
Trident['Returns'].hist(bins = 100,label ='Trident',alpha =0.5 )
Hdfc_bank['Returns'].hist(bins = 100,label ='HDFC Bank',alpha =0.5)
Reliance_industries['Returns'].hist(bins = 100,label ='Reliance',alpha =0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Plotting them in line graph

# %%
Trident['Returns'].plot(label ='Trident' )
Hdfc_bank['Returns'].plot(label ='HDFCBank')
Reliance_industries['Returns'].plot(label ='Reliance')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## CALCULATING EXPECTED RETURNS USING DAILY RETURN AND THIR AVERAGES.

# %%
from datetime import datetime
import yfinance as yf
stocks_list = ["META",
               "AMZN",
               "NFLX",
               "GOOG"]

# %%
start = datetime(datetime.now().year - 1, 
                 datetime.now().month,
                 datetime.now().day)

end = datetime.now()

# %%
for stock in stocks_list:
    try:
        globals()[stock] = yf.download(stock, start=start, end=end)
    except Exception as e:
        print(f"Failed to download data for {stock}: {e}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
META.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   241.375993  245.109166  238.394881  241.882758  241.882758
# std     70.730298   71.216157   69.734364   70.385242   70.385242
# min    109.510002  110.940002  108.540001  109.459999  109.459999
# 25%    183.447502  188.359993  180.265003  184.239994  184.239994
# 50%    261.550003  267.800003  260.085007  264.089996  264.089996
# 75%    301.977501  306.937492  299.127487  301.732506  301.732506
# max    340.130005  342.920013  338.579987  341.489990  341.489990
#
#              Volume
# count  2.520000e+02
# mean   2.543631e+07
# std    1.348565e+07
# min    5.467500e+06
# 25%    1.778448e+07
# 50%    2.177385e+07
# 75%    2.851465e+07
# max    1.504757e+08

# %%
print(AMZN)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-11-29   94.040001   94.410004   91.440002   92.419998   92.419998
# 2022-11-30   92.470001   96.540001   91.529999   96.540001   96.540001
# 2022-12-01   96.989998   97.230003   94.919998   95.500000   95.500000
# 2022-12-02   94.480003   95.360001   93.779999   94.129997   94.129997
# 2022-12-05   93.050003   94.059998   90.820000   91.010002   91.010002
# ...                ...         ...         ...         ...         ...
# 2023-11-22  144.570007  147.740005  144.570007  146.710007  146.710007
# 2023-11-24  146.699997  147.199997  145.320007  146.740005  146.740005
# 2023-11-27  147.529999  149.259995  146.880005  147.729996  147.729996
# 2023-11-28  146.979996  147.600006  145.529999  147.029999  147.029999
# 2023-11-29  147.850006  148.539993  145.970001  146.139999  146.139999
#
#                Volume
# Date
# 2022-11-29   65567300
# 2022-11-30  102805800
# 2022-12-01   68488000
# 2022-12-02   72496400
# 2022-12-05   71535500
# ...               ...
# 2023-11-22   45669100
# 2023-11-24   22378400
# 2023-11-27   53762400
# 2023-11-28   42612600
# 2023-11-29   19257239
#
# [252 rows x 6 columns]

# %%
NFLX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 252 entries, 2022-11-29 to 2023-11-29
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       252 non-null    float64
#  1   High       252 non-null    float64
#  2   Low        252 non-null    float64
#  3   Close      252 non-null    float64
#  4   Adj Close  252 non-null    float64
#  5   Volume     252 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB

# %%
GOOG["High"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
GOOG["Volume"].plot(legend = True,
                    figsize = (14, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
moving_average_intervals = [5, 20, 50]

for moving_average in moving_average_intervals:
    column_name = "moving_average for %s days" %(str(moving_average))
    GOOG[column_name] = GOOG["Adj Close"].rolling(moving_average).mean()

# %%
GOOG[["Adj Close", 
      "moving_average for 5 days", 
      "moving_average for 20 days", 
      "moving_average for 50 days"]].plot(figsize=(14, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
GOOG["Daily Return"] = GOOG["Adj Close"].pct_change()

# %%
GOOG["Daily Return"].plot(figsize = (14, 14),
                          legend = True,
                          linestyle = '--',
                          marker = 'o')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adjusted_closing_dataframe = yf.download(stocks_list,
                            start,
                            end)["Adj Close"]

print(adjusted_closing_dataframe)
# Out:
# [*********************100%%**********************]  4 of 4 completed
#                   AMZN        GOOG        META        NFLX
# Date
# 2022-11-29   92.419998   95.440002  109.459999  280.959991
# 2022-11-30   96.540001  101.449997  118.099998  305.529999
# 2022-12-01   95.500000  101.279999  120.440002  316.950012
# 2022-12-02   94.129997  100.830002  123.489998  320.410004
# 2022-12-05   91.010002   99.870003  122.430000  312.589996
# ...                ...         ...         ...         ...
# 2023-11-22  146.710007  140.020004  341.489990  478.000000
# 2023-11-24  146.740005  138.220001  338.230011  479.559998
# 2023-11-27  147.729996  138.050003  334.700012  479.170013
# 2023-11-28  147.029999  138.619995  338.989990  479.000000
# 2023-11-29  146.270004  137.315002  331.959991  476.130005
#
# [252 rows x 4 columns]

# %%
adjusted_closing_dataframe.head()
# Out:
#                  AMZN        GOOG        META        NFLX
# Date
# 2022-11-29  92.419998   95.440002  109.459999  280.959991
# 2022-11-30  96.540001  101.449997  118.099998  305.529999
# 2022-12-01  95.500000  101.279999  120.440002  316.950012
# 2022-12-02  94.129997  100.830002  123.489998  320.410004
# 2022-12-05  91.010002   99.870003  122.430000  312.589996

# %%
from pandas_datareader import data as pdr
import fix_yahoo_finance

data = pdr.get_data_yahoo('APPL', start='2017-04-23', end='2017-05-24')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [78], in <cell line: 2>()
#       1 from pandas_datareader import data as pdr
# ----> 2 import fix_yahoo_finance
#       4 data = pdr.get_data_yahoo('APPL', start='2017-04-23', end='2017-05-24')
#
# ModuleNotFoundError: No module named 'fix_yahoo_finance'

# %%
stocks_returns = adjusted_closing_dataframe.pct_change()

print(stocks_returns)
# Out:
#                 AMZN      GOOG      META      NFLX
# Date
# 2022-11-29       NaN       NaN       NaN       NaN
# 2022-11-30  0.044579  0.062971  0.078933  0.087450
# 2022-12-01 -0.010773 -0.001676  0.019814  0.037378
# 2022-12-02 -0.014346 -0.004443  0.025324  0.010917
# 2022-12-05 -0.033146 -0.009521 -0.008584 -0.024406
# ...              ...       ...       ...       ...
# 2023-11-22  0.019528  0.010100  0.013384  0.006422
# 2023-11-24  0.000204 -0.012855 -0.009546  0.003264
# 2023-11-27  0.006747 -0.001230 -0.010437 -0.000813
# 2023-11-28 -0.004738  0.004129  0.012817 -0.000355
# 2023-11-29 -0.005169 -0.009414 -0.020738 -0.005992
#
# [252 rows x 4 columns]

# %%
import seaborn as sns
sns.jointplot("GOOG", 
                  "GOOG",
                  data = stocks_returns,
                  color = "orange")
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("AMZN",
                  "NFLX",
                  data = stocks_returns)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(data = stocks_returns.dropna())

# %%
returns_figure = sns.PairGrid(data = adjusted_closing_dataframe)

# %%
returns_figure.map_upper(pyplot.scatter)
returns_figure.map_diag(pyplot.hist, bins = 30)
returns_figure.map_lower(seaborn.kdeplot)

# %%
correlations = stocks_returns.corr()
sns.heatmap(data = correlations,
                fmt = "6g")
returns = stocks_returns.dropna()

# %%
import numpy

circles_area = numpy.pi * 15
pyplot.scatter(x = returns.mean(),
               y = returns.std(), 
               s = circles_area)
pyplot.xlabel("Expected Returns")
pyplot.ylabel("Risk")
for label, x, y in zip(returns.columns, 
                       returns.mean(), 
                       returns.std()):
    pyplot.annotate(label, 
                  xy = (x, y),
                  xytext = (50, 50),
                  textcoords = "offset points",
                  ha = "right",
                  va = "bottom",
                  arrowprops = dict(arrowstyle = "-",
                                    connectionstyle = "arc3, rad = -0.3"))
